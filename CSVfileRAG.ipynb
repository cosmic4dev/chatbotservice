# %%
#install
# !pip install langchain-experimental
# !pip install openai
# !pip install tabulate #테이블 형태의 데이터를 텍스트 데이터 형식으로 출력함.
# !pip install pandas
# !pip install -U langchain-community
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 31.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/data/booksv_02.csv")
df.head()
# Out:
#             title subtitle                          authors  \
# 0          Gilead      NaN               Marilynne Robinson
# 1    Spider's Web  A Novel  Charles Osborne;Agatha Christie
# 2    The One Tree      NaN             Stephen R. Donaldson
# 3  Rage of angels      NaN                   Sidney Sheldon
# 4  The Four Loves      NaN              Clive Staples Lewis
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2               American fiction
# 3                        Fiction
# 4                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# 3  http://books.google.com/books/content?id=FKo2T...
# 4  http://books.google.com/books/content?id=XhQ5X...
#
# ...

# %%
import os
import pandas as pd
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType
os.environ["OPENAI_API_KEY"] = ""

# 에이전트 생성
agent = create_pandas_dataframe_agent(
    ChatOpenAI(temperature=0, model='gpt-3.5-turbo'),
    df,
    verbose=False,
    agent_type=AgentType.OPENAI_FUNCTIONS,
    allow_dangerous_code=True                          # 위험한 코드 실행 허용
)

# %%
#질문 test1
question = "데이터프레임에서 첫 번째 행의 데이터를 보여줘."
response = agent.run(question)
print(response)
# Out:
# 첫 번째 행의 데이터는 다음과 같습니다:
# - 제목: Gilead
# - 부제: NaN
# - 작가: Marilynne Robinson
# - 카테고리: Fiction
# - 썸네일: [링크](http://books.google.com/books/content?id=KQZCPgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api)
# ...

# %%
#질문 test2
agent.run("어떤 제품의 ratings_count가 제일 높아?")
# Out:
# '가장 높은 ratings_count를 가진 제품은 "One Hundred Years of Solitude"입니다. 해당 제품의 ratings_count는 547,207입니다.'

# %%
#질문 test3
question = "가장 최근에 출간된 책은?"
response=agent.run(question)
print(response)
# Out:
# 가장 최근에 출간된 책은 "The Yiddish Policemen's Union"입니다.
